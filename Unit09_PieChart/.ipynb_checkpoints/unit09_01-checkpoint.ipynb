# %% [markdown]
# # 파이 차트로 나타내기

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv')
data = csv.reader(f)
m = []
f = []
name = input('찾고 싶은 지역의 이름을 입력하세요 : ')

for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(int(i.replace(',','')))
        for i in row[106:] :
            f.append(-int(i.replace(',','')))
        break

#print(len(m), len(f))
            
#plt.style.use('ggplot')
plt.figure(figsize = (10, 5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name + '지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()

# %% [markdown]
# 두 지역이 같은 이름을 갖고 있을 경우는 어떻게 해야 할까? --> Later

# %% [markdown]
# ## 파이 차트로 나타내기

# %%
import matplotlib.pyplot as plt
plt.pie([10, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
size = [2441, 2312, 1031, 1233]
plt.axis('equal')
plt.pie(size)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
size = [2441, 2312, 1031, 1233]
label = ['A', 'B', 'AB', 'O']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%1.f%%')
plt.legend()
plt.show()

# %% [markdown]
# autopct는 auto_percent의 의미.

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
size = [2441, 2312, 1031, 1233]
label = ['A', 'B', 'AB', 'O']
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%f.1%%', colors=color, explode=(0, 0, 0.1, 0))
plt.legend()
plt.show()

# %%
import csv

f = open('gender.csv')
data = csv.reader(f)
size = []
name = input('찾고 싶은 지역 이름? (시 단위) : ')
print()

for row in data:
    if name in row[0]:
        m = 0
        f = 0
        for i in range(101):
            m += int(row[i+3].replace(',',''))
            f += int(row[i+106].replace(',',''))
        break
size.append(m)
size.append(f)

print('{0} 지역의 남녀 인구수는\n{1}'.format(name, size))
# Out:
# 찾고 싶은 지역 이름? (시 단위) : 울산광역시
#
# 울산광역시 지역의 남녀 인구수는
# [591449, 559852]

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv')
data = csv.reader(f)
size = []
name = input('찾고 싶은 지역 이름? (시 단위) : ')
print()
for row in data:
    if name in row[0]:
        m = 0
        f = 0
        for i in range(101):
            m += int(row[i+3].replace(',',''))
            f += int(row[i+106].replace(',',''))
        break
size.append(m)
size.append(f)
print('{0} 지역의 남녀 인구수는\n남:{1}, 여:{2}'.format(name, size[0], size[1]))

plt.rc('font', family='Malgun Gothic')
color = ['crimson', 'darkcyan']
plt.axis('equal')
plt.pie(size, labels=['남', '여'], autopct='%.1f%%', colors=color, startangle=-90)
plt.title(name+' 지역의 남녀 성별 비율')
plt.show()
# Out:
# 찾고 싶은 지역 이름? (시 단위) : 울산광역시
#
# 울산광역시 지역의 남녀 인구수는
# 남:591449, 여:559852

# %% [markdown]
# startangle 속성은 0도에서 시작함.
