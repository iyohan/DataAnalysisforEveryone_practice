# %%
import matplotlib.pyplot as plt
plt.plot([10, 20, 30, 40])
plt.show()

# %% [markdown]
# Indexes are used as x-values for the graph.

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [12, 43, 25, 15])
plt.show()
